# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(
    data= "dataset_YOLO(2)/custom.yaml",
    epochs=50,          
    imgsz=640,          
    batch=16   
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.145 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.139  Python-3.13.3 torch-2.7.0+cpu CPU (12th Gen Intel Core(TM) i7-1255U)
# ...
